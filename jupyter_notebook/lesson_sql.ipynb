# %%
select version();
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>version()</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.0.18</td>
#     </tr>
#   </tbody>
# </table>

# %%
use seata;
# Out:
# yes

# %%
show tables;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tables_in_seata</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>failed_jobs</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>migrations</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>password_resets</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>personal_access_tokens</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>sessions</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>users</td>
#     </tr>
#   </tbody>
# </table>

# %%
use edu;
# Out:
# yes

# %%
desc article;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Field</th>
#       <th>Type</th>
#       <th>Null</th>
#       <th>Key</th>
#       <th>Default</th>
#       <th>Extra</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>id</td>
#       <td>int(10) unsigned</td>
#       <td>NO</td>
#       <td>PRI</td>
#       <td>None</td>
#       <td>auto_increment</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>cid</td>
#       <td>varchar(255)</td>
#       <td>YES</td>
#       <td></td>
#       <td>1</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>title</td>
#       <td>varchar(255)</td>
#       <td>NO</td>
#       <td></td>
#       <td>None</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>author</td>
#       <td>varchar(255)</td>
#       <td>YES</td>
#       <td></td>
#       <td>None</td>
#       <td></td>
#     </tr>
#     <tr>
# ...

# %%
desc article_category;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Field</th>
#       <th>Type</th>
#       <th>Null</th>
#       <th>Key</th>
#       <th>Default</th>
#       <th>Extra</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>id</td>
#       <td>int(10) unsigned</td>
#       <td>NO</td>
#       <td>PRI</td>
#       <td>None</td>
#       <td>auto_increment</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>pid</td>
#       <td>int(11)</td>
#       <td>NO</td>
#       <td></td>
#       <td>0</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>title</td>
#       <td>varchar(255)</td>
#       <td>NO</td>
#       <td></td>
#       <td>None</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>intr</td>
#       <td>varchar(255)</td>
#       <td>YES</td>
#       <td></td>
#       <td>None</td>
#       <td></td>
#     </tr>
#     <tr>
# ...

# %%
use django_mysql;
# Out:
# yes

# %%
desc auth_group;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Field</th>
#       <th>Type</th>
#       <th>Null</th>
#       <th>Key</th>
#       <th>Default</th>
#       <th>Extra</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>id</td>
#       <td>int(11)</td>
#       <td>NO</td>
#       <td>PRI</td>
#       <td>None</td>
#       <td>auto_increment</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>name</td>
#       <td>varchar(150)</td>
#       <td>NO</td>
#       <td>UNI</td>
#       <td>None</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %%
desc auth_permission;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Field</th>
#       <th>Type</th>
#       <th>Null</th>
#       <th>Key</th>
#       <th>Default</th>
#       <th>Extra</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>id</td>
#       <td>int(11)</td>
#       <td>NO</td>
#       <td>PRI</td>
#       <td>None</td>
#       <td>auto_increment</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>name</td>
#       <td>varchar(255)</td>
#       <td>NO</td>
#       <td></td>
#       <td>None</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>content_type_id</td>
#       <td>int(11)</td>
#       <td>NO</td>
#       <td>MUL</td>
#       <td>None</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>codename</td>
#       <td>varchar(100)</td>
#       <td>NO</td>
#       <td></td>
#       <td>None</td>
#       <td></td>
#     </tr>
# ...

# %%
select * from auth_group;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
select * from auth_permission;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>content_type_id</th>
#       <th>codename</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Can add log entry</td>
#       <td>2</td>
#       <td>add_logentry</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Can change log entry</td>
#       <td>2</td>
#       <td>change_logentry</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Can delete log entry</td>
#       <td>2</td>
#       <td>delete_logentry</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Can view log entry</td>
#       <td>2</td>
#       <td>view_logentry</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Can add permission</td>
#       <td>3</td>
#       <td>add_permission</td>
#     </tr>
#     <tr>
# ...

# %%
desc auth_user;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Field</th>
#       <th>Type</th>
#       <th>Null</th>
#       <th>Key</th>
#       <th>Default</th>
#       <th>Extra</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>id</td>
#       <td>int(11)</td>
#       <td>NO</td>
#       <td>PRI</td>
#       <td>None</td>
#       <td>auto_increment</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>password</td>
#       <td>varchar(128)</td>
#       <td>NO</td>
#       <td></td>
#       <td>None</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>last_login</td>
#       <td>datetime(6)</td>
#       <td>YES</td>
#       <td></td>
#       <td>None</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>is_superuser</td>
#       <td>tinyint(1)</td>
#       <td>NO</td>
#       <td></td>
#       <td>None</td>
#       <td></td>
#     </tr>
# ...

# %%
desc auth_user_groups;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Field</th>
#       <th>Type</th>
#       <th>Null</th>
#       <th>Key</th>
#       <th>Default</th>
#       <th>Extra</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>id</td>
#       <td>int(11)</td>
#       <td>NO</td>
#       <td>PRI</td>
#       <td>None</td>
#       <td>auto_increment</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>user_id</td>
#       <td>int(11)</td>
#       <td>NO</td>
#       <td>MUL</td>
#       <td>None</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>group_id</td>
#       <td>int(11)</td>
#       <td>NO</td>
#       <td>MUL</td>
#       <td>None</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %%
select * from auth_user_groups;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>user_id</th>
#       <th>group_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>

# %%
insert into auth_user_groups(id, user_id, group_id) values(2, 1, 2);
# Out:
# yes

# %%
insert into auth_group(id, name) values(1, 'admin');
# Out:
# yes

# %%
insert into auth_group(id, name) values(2, 'user');
# Out:
# yes

# %%
desc auth_user_user_permissions;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Field</th>
#       <th>Type</th>
#       <th>Null</th>
#       <th>Key</th>
#       <th>Default</th>
#       <th>Extra</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>id</td>
#       <td>int(11)</td>
#       <td>NO</td>
#       <td>PRI</td>
#       <td>None</td>
#       <td>auto_increment</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>user_id</td>
#       <td>int(11)</td>
#       <td>NO</td>
#       <td>MUL</td>
#       <td>None</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>permission_id</td>
#       <td>int(11)</td>
#       <td>NO</td>
#       <td>MUL</td>
#       <td>None</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %%
select * from auth_user_user_permissions;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
select DATE("Y-m-d", now());
# Out:
# (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ', now())' at line 1")

# %%
select now()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>now()</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2021-05-01 22:21:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
show databases;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Database</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>db_account</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>db_example</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>db_order</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>db_storage</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>django_mysql</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>edu</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>fastapi_admin</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>growthpro_db</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>homestead</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>information_schema</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>mysql</td>
#     </tr>
#     <tr>
#       <th>11</th>
# ...

# %%
use mysql;
# Out:
# yes

# %%
show tables;
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tables_in_mysql</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>columns_priv</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>component</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>db</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>default_roles</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>engine_cost</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>func</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>general_log</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>global_grants</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>gtid_executed</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>help_category</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>help_keyword</td>
#     </tr>
#     <tr>
#       <th>11</th>
# ...
